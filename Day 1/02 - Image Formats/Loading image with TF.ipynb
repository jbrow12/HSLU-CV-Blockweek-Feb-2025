# %% [markdown]
# # Loading Images with TensorFlow
#
# Tested with Pythzon 3.8.20 and TF 2.13.

# %%
# %pip install tensorflow==2.13.0
# Out:
# Requirement already satisfied: tensorflow==2.13.0 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (2.13.0)
# Requirement already satisfied: tensorflow-intel==2.13.0 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from tensorflow==2.13.0) (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (25.1.24)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (18.1.1)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.4.0)
# Requirement already satisfied: packaging in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (4.25.6)
# Requirement already satisfied: setuptools in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (56.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.4.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.70.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.13.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.45.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.0.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (8.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.1.5)
# Requirement already satisfied: zipp>=3.20 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.20.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pillow
# Out:
# Requirement already satisfied: pillow in c:\users\jayca\switchdrive\syncvm\3. fall24\cvi03_computer vision\.venv\lib\site-packages (10.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
import PIL

# %%
print(tf.__version__)
# Out:
# 2.13.0

# %%
print(PIL.__version__)
# Out:
# 10.4.0

# %%
# %cd "C:\Users\jayca\switchdrive\SyncVM\3. Fall24\CVI03_Computer Vision\HSLU-CV-Blockweek-Feb-2025\Day 1\02 - Image Formats"
# Out:
# c:\Users\jayca\switchdrive\SyncVM\3. Fall24\CVI03_Computer Vision\HSLU-CV-Blockweek-Feb-2025\Day 1\02 - Image Formats

# %%
image_loaded = tf.keras.utils.load_img('HSLU.jpeg')

# %%
image_loaded
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=782x336>

# %%
image_loaded.size
# Out:
# (782, 336)

# %%
image_loaded.mode
# Out:
# 'RGB'

# %%
type(image_loaded)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
image_loaded = tf.keras.utils.load_img('HSLU.jpeg', color_mode= "grayscale")

# %%
image_loaded
# Out:
# <PIL.Image.Image image mode=L size=782x336>

# %%
image_loaded.mode
# Out:
# 'L'

# %%
im = PIL.Image.open("HSLU.jpeg")
im.show()

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=782x336>

# %%
im.format
# Out:
# 'JPEG'

# %%
im.size
# Out:
# (782, 336)

# %%
im.info
# Out:
# {'exif': b'Exif\x00\x00II*\x00\x08\x00\x00\x00\x01\x00\x98\x82\x02\x00\x15\x00\x00\x00\x1a\x00\x00\x00\x00\x00\x00\x00Ingo Hoehn/dphoto.ch\x00\x00\x00\x00',
#  'xmp': b'<?xpacket begin="\xef\xbb\xbf" id="W5M0MpCehiHzreSzNTczkc9d"?> <x:xmpmeta xmlns:x="adobe:ns:meta/" x:xmptk="Adobe XMP Core 5.6-c148 79.164036, 2019/08/13-01:06:57        "> <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"> <rdf:Description rdf:about="" xmlns:xmpMM="http://ns.adobe.com/xap/1.0/mm/" xmlns:stRef="http://ns.adobe.com/xap/1.0/sType/ResourceRef#" xmlns:xmp="http://ns.adobe.com/xap/1.0/" xmlns:dc="http://purl.org/dc/elements/1.1/" xmpMM:OriginalDocumentID="xmp.did:e31986f4-4ce4-4546-afd4-bb93e3b7cabb" xmpMM:DocumentID="xmp.did:F593A2D39E9511EB94ADE580D0F5FF44" xmpMM:InstanceID="xmp.iid:F593A2D29E9511EB94ADE580D0F5FF44" xmp:CreatorTool="Capture One 12 Macintosh"> <xmpMM:DerivedFrom stRef:instanceID="xmp.iid:e17222fd-4201-2448-96b2-3c52bb4e8140" stRef:documentID="adobe:docid:photoshop:07cabdb5-644a-7e4d-b974-f0cf1c6cf109"/> <dc:rights> <rdf:Alt> <rdf:li xml:lang="x-default">Ingo Hoehn/dphoto.ch</rdf:li> </rdf:Alt> </dc:rights> <dc:creator> <rdf:Seq> <rdf:li>Hoehn Ingo</rdf:li> </rdf:Seq> </dc:creator> </rdf:Description> </rdf:RDF> </x:xmpmeta> <?xpacket end="r"?>',
#  'photoshop': {1028: b'\x1c\x01Z\x00\x03\x1b%G\x1c\x02\x00\x00\x02\x00\x02\x1c\x02t\x00\x14Ingo Hoehn/dphoto.ch',
#   1061: b'\x8e\x89FH\xcb+/D\x96\xa4\x12}P\x85{\x11'},
#  'adobe': 100,
#  'adobe_transform': 1,
#  'progressive': 1,
#  'progression': 1,
#  'dpi': (72, 72)}
